# %%
import numpy as np
import cv2
import matplotlib.pylab as plt
import matplotlib.image as mpimg
from itertools import product

bicycle = mpimg.imread('bicycle.png')
bicycle = (bicycle * 255).astype(np.uint8)
blurcycle = cv2.GaussianBlur(bicycle, (5, 5), 0)

edges = cv2.Canny(blurcycle, 100, 200)


def make_hough_lines(image, rho=1, theta=np.pi/180):
    lines = cv2.HoughLinesP(image, rho=rho, theta=theta, threshold=100)
    lines = lines.reshape((lines.shape[0], lines.shape[2]))
    for x1, y1, x2, y2 in lines:
        cv2.line(image, (x1, y1), (x2, y2), [255, 0, 0], 3)
    plt.imshow(image, cmap='gray')
    plt.show()

rhos = [1, 2, 5, 10]
# thetas = [np.pi/30, np.pi/60, np.pi/180]
thetas = [np.pi/10, np.pi/20, np.pi/30, np.pi/40]

for rho, theta in product(rhos, thetas):
    print("Rho", rho, "; Theta", np.pi/theta)
    edges = cv2.Canny(blurcycle, 100, 200)
    make_hough_lines(edges, rho, theta)
# Out:
# Rho 1 ; Theta 10.0
# Rho 1 ; Theta 20.0
# Rho 1 ; Theta 30.0
# Rho 1 ; Theta 40.0
# Rho 2 ; Theta 10.0
# Rho 2 ; Theta 20.0
# Rho 2 ; Theta 30.0
# Rho 2 ; Theta 40.0
# Rho 5 ; Theta 10.0
# Rho 5 ; Theta 20.0
# Rho 5 ; Theta 30.0
# Rho 5 ; Theta 40.0
# Rho 10 ; Theta 10.0
# Rho 10 ; Theta 20.0
# Rho 10 ; Theta 30.0
# Rho 10 ; Theta 40.0
